# %%
#MatplotLib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({"Length": np.random.randn(500)})
df.head()
# Out:
#      Length
# 0 -0.274816
# 1  1.709757
# 2  0.040941
# 3 -1.431717
# 4 -0.240770

# %%
#Histogram
df['Length'].hist() #using pandas
plt.show()

# %%
plt.hist(df['Length'], bins=15)
plt.show()

# %%
plt.hist(df['Length'],bins=15)
plt.show()

# %%
plt.hist(df['Length'],bins=15)
plt.xlabel("Length")
plt.ylabel("Count")
plt.tilte("Histogram of length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 plt.xlabel("Length")
#       3 plt.ylabel("Count")
# ----> 4 plt.tilte("Histogram of length")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tilte'

# %%
import matplotlib.pyplot as plt

# %%
#horizontal orientatio
plt.hist(df['Length'], bins=15, orientation='horizontal')
plt.xlabel("Length in mm.")
plt.ylabel("Count")
plt.title("Histogram of piece length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #horizontal orientatio
# ----> 2 plt.hist(df['Length'], bins=15, orientation='horizontal')
#       3 plt.xlabel("Length in mm.")
#       4 plt.ylabel("Count")
#
# NameError: name 'df' is not defined

# %%
plt.boxplot(df['Length'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.boxplot(df['Length'])
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.boxplot(df['Length'],notch=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.boxplot(df['Length'],notch=True)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#scatter plot
x=np.arange(1,11)
y=np.arange(11,21)
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('2D Scatter plot')
plt.show()

# %%
x = [1,2.1,0.4,8.9,7.1,0.1,3,5.1,6.1,3.4,2.9,9]
y = [1,3.4,0.7,1.3,9,0.4,4,1.9,9,0.3,4.0,2.9]
plt.scatter(x,y,color='red')
plt.ylabel('some numbers')
plt.xlabel('some more numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Line plot
#Creating a line chart of single list
plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13])
plt.show()

# %%
plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13],color='green',linewidth=5.0)
plt.title('chart with user defined color and width of line')
plt.xlabel('X axix') #label on x-axis.
plt.ylabel('Y axix') #label on y-axix
plt.show()

# %%
plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13],colors='green',linewidth=5.0)
plt.title('chart with user defined color and width of line')
plt.xlabel('X axix')
plt.ylabel('Y axix')
plt.grid() #Displaying a grid.
plt.text(4,12,'Green colored Line')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13],colors='green',linewidth=5.0)
#       2 plt.title('chart with user defined color and width of line')
#       3 plt.xlabel('X axix')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...

# %%
x = [1,2.1,0.4,8.9,7.1,0.1,3,5.1,6.1,3.4,2.9,9]
y = [1,3.4,0.7,1.3,9,0.4,4,1.9,9,0.3,4.0,2.9]
plt.plot(x,y,color='blue',marker='+',linestyle='--',markersize=10)
plt.show()

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)
plt.plot(x,y,color='blue',marker='+',linestyle='--',marker='+',linestyle='--',markersize=10)
plt.show()
# Out:
#   Cell In[12], line 3
#     plt.plot(x,y,color='blue',marker='+',linestyle='--',marker='+',linestyle='--',markersize=10)
#                                                         ^
# SyntaxError: keyword argument repeated: marker

# %%
x=np.arange(0,10)
y=np.arange(11,21)
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=10)
plt.xlabel('X  axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
plt.show()

# %%
x = np.linespace(0,2,100)

plot.plot(x,x, label='linear') #plot some data on the (implicit) axes.
plot.plot(x,x**2, label='quadratic') #etc
plot.plot(x,x**3, label='cubic')

plt.xlabel('X label')
plt.ylabel('Y label')
plt.title("Simple Plot")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x = np.linespace(0,2,100)
#       3 plot.plot(x,x, label='linear') #plot some data on the (implicit) axes.
#       4 plot.plot(x,x**2, label='quadratic') #etc
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'linespace'

# %%
days = [1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

plt.plot(days, max_t, label="max")
plt.plot(days, min_t,label="min")
plt.plot(days,avg_t,label="average")

#set axes labels and chart title
plt.xlabel('Day')
plt.yalbel('Temperature')
plt.title('Weather')

#set legend
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 12
#      10 #set axes labels and chart title
#      11 plt.xlabel('Day')
# ---> 12 plt.yalbel('Temperature')
#      13 plt.title('Weather')
#      15 #set legend
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'yalbel'

# %%
#legend at different location with shadow enabled and fontsize set to large
plt.plot(days,max_t, label="max")
plt.plot(days,avg_t, label="average")

plt.legend(loc='upper right',shadow=True,fontsize='small')
plt.show()

# %%
## Creating subplots

x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

plt.subplot(2,2,1)
plt.plot(x,y,'r--')

plt.subplot(2,2,2)
plt.plot(x,y,'g*--')

plt.subplot(2,2,3)
plt.plot(x,y,'bo',linewidth=2,linestyle='dashed')

plt.subplot(2,2,4)
plt.plot(x,y,'go',linetyle='dashed')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 16
#      13 plt.plot(x,y,'bo',linewidth=2,linestyle='dashed')
#      15 plt.subplot(2,2,4)
# ---> 16 plt.plot(x,y,'go',linetyle='dashed')
#      18 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
#pie chart
list=[20,80,15,10,20,5]
lbs=['FaceCream','FaceWash','Toothpaste','Bathing soap','Shampoo''Moisture']

# %%
#Craeting and Dsiplaying a pie chart
plt.pie(list,labels=lbs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 #Craeting and Dsiplaying a pie chart
# ----> 2 plt.pie(list,labels=lbs)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
#    3548         explode=explode,
#    3549         labels=labels,
#    3550         colors=colors,
#    3551         autopct=autopct,
#    3552         pctdistance=pctdistance,
# ...

# %%
#Creating and displaying a pie chart
plt.pie(list,labels=lbs,autopct='%1.1f%%
